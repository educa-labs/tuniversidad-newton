# %%
import numpy as np
import pandas as pd
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.preprocessing import scale,LabelEncoder
from sklearn.model_selection import StratifiedShuffleSplit,train_test_split
from sklearn.metrics import accuracy_score

# %%
def print_metrics(y_true,y_pred):
    print("accurracy: {}".format(accuracy_score(y_true,y_pred)))
    #print("f1: {}".format(f1_score(y_true,y_pred,average="macro")))

# %%
folder = '../relevant_data/area_data'
test_scores = np.array(pd.read_csv('test_recomendations.csv'))
for file in os.listdir(folder):
    data = pd.read_csv(os.path.join(folder, file))
    X = np.array(data[["mat","len","cie","his","nem"]])
    y = np.array(data.apply(lambda x: "{}/{}".format(x['universidad'],x['tuni_carreer_name']),axis=1))
#     lb = LabelEncoder()
#     lb.fit(y)
#     y_encoded = lb.transform(y)
    #X_scaled = scale(X)
    #randomized stratified test/train split
    print(file)
    sss = StratifiedShuffleSplit(n_splits=5, train_size=0.8, random_state=0)
    try:
        for train_index,test_index in sss.split(X, y):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            model = RandomForestClassifier(25,min_samples_split=5,n_jobs=-1)
            model.fit(X_train,y_train)
            result = model.predict(X_test)
            print_metrics(y_test,result)
    except ValueError:
        print("{} failed!".format(file))
    model = RandomForestClassifier(25,min_samples_split=5,n_jobs=-1)
    model.fit(X,y)
    clases = model.classes_
    result = model.predict_proba(test_scores)
    for i in range(test_scores.shape[0]):
        print(test_scores[i])
        best = np.argpartition(result[i],-3)[-3:]
        for index in best:
            print("{}, prob: {}".format(clases[index],result[i][index]))
# Out:
# 9_data.csv
# accurracy: 0.09275584515139901
# accurracy: 0.10348792640858566
# accurracy: 0.09850517439632044
# accurracy: 0.10080490609428899
# accurracy: 0.09428899961671139
# [830 700 778   0 720]
# UACH/medicina , prob: 0.14576190476190476
# UFRO/medicina, prob: 0.2
# UCH/medicina , prob: 0.19428571428571428
# [830 700 778 680 720]
# UNAB/medicina, prob: 0.10133333333333333
# UFRO/medicina, prob: 0.17
# UCH/medicina , prob: 0.21904761904761902
# [500 450 580   0 670]
# UANT/obstetricia puericultura, prob: 0.05333333333333333
# UANT/bachillerato  ciencias salud, prob: 0.055111111111111104
# UCSC/nutrición dietética, prob: 0.06253968253968253
# [400 430   0 450 500]
# UNAB/psicología, prob: 0.15066666666666667
# UMAYO/medicina veterinaria, prob: 0.2091111111111111
# UTA/psicología, prob: 0.22333333333333336
# [620 730   0 680 620]
# UDEC/psicología, prob: 0.10933333333333334
# UV/enfermería , prob: 0.11066666666666666
# UDP/psicología, prob: 0.5350476190476191
# 2_data.csv
# accurracy: 0.2553191489361702
# accurracy: 0.3120567375886525
# accurracy: 0.3475177304964539
# accurracy: 0.2907801418439716
# accurracy: 0.3120567375886525
# [830 700 778   0 720]
# UACH/agronomía , prob: 0.15533333333333335
# UCH/ingeniería agrónoma, prob: 0.21799999999999997
# UCH/ingeniería recursos naturales renovables, prob: 0.5286666666666666
# [830 700 778 680 720]
# UACH/agronomía , prob: 0.14733333333333334
# UCH/ingeniería agrónoma, prob: 0.32866666666666666
# UCH/ingeniería recursos naturales renovables, prob: 0.434
# [500 450 580   0 670]
# UCM/agronomía, prob: 0.0928888888888889
# UDEC/agronomía, prob: 0.19595238095238096
# UACH/agronomía , prob: 0.25066666666666665
# [400 430   0 450 500]
# UMAYO/agronomía, prob: 0.1364935064935065
# UCT/agronomía, prob: 0.2
# UMAYO/ingeniería forestal, prob: 0.5296969696969697
# [620 730   0 680 620]
# UCH/ingeniería recursos naturales renovables, prob: 0.08
# UCH/ingeniería agrónoma, prob: 0.7633333333333333
# PUCV/agronomía, prob: 0.09428571428571429
# 11_data.csv
# accurracy: 0.09213274541656997
# accurracy: 0.09166860060338826
# accurracy: 0.08470642840566257
# accurracy: 0.08447435599907172
# accurracy: 0.08563471803202599
# [830 700 778   0 720]
# UTFSM/ingeniería civil electrónica , prob: 0.013333333333333332
# PUC/ingeniería, prob: 0.10533333333333333
# UCH/ingeniería ciencias   plan común, prob: 0.86
# [830 700 778 680 720]
# UAI/ingeniería civil industrial, prob: 0.04
# UCH/ingeniería ciencias   plan común, prob: 0.67
# PUC/ingeniería, prob: 0.24009523809523806
# [500 450 580   0 670]
# UTEM/ingeniería biotecnología, prob: 0.06538095238095237
# UANT/tecnología médica, prob: 0.07619047619047618
# UNAB/tecnología médica, prob: 0.07593650793650794
# [400 430   0 450 500]
# UNAB/ingeniería industrial, prob: 0.14533333333333334
# UNAB/ingeniería comercial, prob: 0.18933333333333333
# UNAB/ingeniería administración empresas, prob: 0.3709523809523809
# [620 730   0 680 620]
# UAI/ingeniería comercial, prob: 0.10800000000000001
# UDP/ingeniería comercial, prob: 0.11266666666666665
# UCM/ingeniería comercial, prob: 0.11333333333333333
# 7_data.csv
# 7_data.csv failed!
# [830 700 778   0 720]
# UACH/pedagogía historia ciencias sociales, prob: 0.10142857142857142
# PUC/pedagogía educación media matemática, prob: 0.3212857142857143
# USACH/bachillerato ciencias humanidades , prob: 0.17752380952380953
# [830 700 778 680 720]
# USACH/pedagogía física matemática   licenciatura educación física matemática , prob: 0.07200000000000001
# UACH/pedagogía historia ciencias sociales, prob: 0.07266666666666667
# UMCE/lic  educ  física pedagogía física  con menciones , prob: 0.16666666666666663
# [500 450 580   0 670]
# UCM/pedagogía matemática computación, prob: 0.08800000000000001
# UCM/pedagogía educación física, prob: 0.10066666666666667
# UNAB/bachillerato ciencias, prob: 0.23
# [400 430   0 450 500]
# UNAB/educación musical, prob: 0.1238095238095238
# UNAB/educación física, prob: 0.3755238095238095
# UNAB/educación parvularia, prob: 0.21066666666666667
# [620 730   0 680 620]
# UMAYO/pedagogía educación diferencial mención discapacidades intelectual múltiples, prob: 0.08266666666666665
# USACH/pedagogía inglés   licenciatura educación inglés, prob: 0.11599999999999999
# UMCE/lic  educ  mención inglés pedagogía inglés, prob: 0.156
# 6_data.csv
# accurracy: 0.32238193018480493
# accurracy: 0.27720739219712526
# accurracy: 0.3326488706365503
# accurracy: 0.33059548254620125
# accurracy: 0.32854209445585214
# [830 700 778   0 720]
# UCH/derecho  lic  ciencias jurídicas sociales, prob: 0.18444444444444447
# UDD/derecho   santiago, prob: 0.1917142857142857
# UCN/derecho   sede coquimbo, prob: 0.2680952380952381
# [830 700 778 680 720]
# UTAL/derecho   talca, prob: 0.13
# UCH/derecho  lic  ciencias jurídicas sociales, prob: 0.3031111111111111
# PUC/derecho, prob: 0.4571111111111111
# [500 450 580   0 670]
# UDA/derecho, prob: 0.11777777777777779
# UDD/derecho   santiago, prob: 0.18266666666666664
# UNAB/derecho, prob: 0.41053968253968265
# [400 430   0 450 500]
# UCN/derecho   sede coquimbo, prob: 0.0
# UDA/derecho, prob: 0.05333333333333333
# UNAB/derecho, prob: 0.9466666666666668
# [620 730   0 680 620]
# PUCV/derecho, prob: 0.14174603174603173
# UAI/derecho, prob: 0.25666666666666665
# UDP/derecho, prob: 0.2711111111111111
# 3_data.csv
# accurracy: 0.1339421613394216
# accurracy: 0.1141552511415525
# accurracy: 0.1050228310502283
# accurracy: 0.1111111111111111
# accurracy: 0.1171993911719939
# [830 700 778   0 720]
# UAI/diseño, prob: 0.06266666666666666
# UTFSM/arquitectura, prob: 0.16476190476190475
# PUC/arquitectura, prob: 0.7078095238095239
# [830 700 778 680 720]
# UAI/diseño, prob: 0.029333333333333336
# PUC/diseño, prob: 0.14685714285714288
# PUC/arquitectura, prob: 0.7350476190476191
# [500 450 580   0 670]
# UTA/diseño multimedia, prob: 0.10533333333333333
# UCN/arquitectura, prob: 0.114
# UV/diseño, prob: 0.12
# [400 430   0 450 500]
# UFT/diseño, prob: 0.1
# UFT/arquitectura, prob: 0.13966666666666666
# UNAB/arquitectura, prob: 0.3907142857142857
# [620 730   0 680 620]
# UCH/geografía, prob: 0.0957777777777778
# PUC/arte, prob: 0.14222222222222222
# PUC/actuación , prob: 0.10288888888888889
# 8_data.csv
# accurracy: 0.5277777777777778
# accurracy: 0.6944444444444444
# accurracy: 0.6388888888888888
# accurracy: 0.5833333333333334
# accurracy: 0.4722222222222222
# [830 700 778   0 720]
# UTA/licenciatura lenguaje comunicación, prob: 0.15485714285714286
# UANDE/bachillerato humanidades, prob: 0.22133333333333333
# PUC/filosofía, prob: 0.4500952380952381
# [830 700 778 680 720]
# USACH/licenciatura historia , prob: 0.074
# PUC/filosofía, prob: 0.2857142857142857
# PUC/historia, prob: 0.48390476190476195
# [500 450 580   0 670]
# UTA/licenciatura inglés, prob: 0.1278095238095238
# UANDE/bachillerato humanidades, prob: 0.19047619047619047
# UTA/licenciatura lenguaje comunicación, prob: 0.5440952380952381
# [400 430   0 450 500]
# UDEC/licenciatura historia, prob: 0.02
# UNAP/traducción inglés   español, prob: 0.5716666666666667
# UTA/licenciatura lenguaje comunicación, prob: 0.4083333333333334
# [620 730   0 680 620]
# USACH/licenciatura historia , prob: 0.08333333333333331
# PUC/historia, prob: 0.24200000000000002
# PUC/filosofía, prob: 0.5813333333333334
# 5_data.csv
# accurracy: 0.23433874709976799
# accurracy: 0.2273781902552204
# accurracy: 0.23433874709976799
# accurracy: 0.2668213457076566
# accurracy: 0.2296983758700696
# [830 700 778   0 720]
# PUC/biología, prob: 0.07333333333333333
# PUC/bioquímica, prob: 0.5800952380952381
# UACH/geología , prob: 0.1575238095238095
# [830 700 778 680 720]
# UCH/lengua literatura hispánicas, prob: 0.12866666666666665
# UCH/antropología    arquelogía  lic  antropología mención antropología, prob: 0.18433333333333335
# UCH/psicología  lic  psicología , prob: 0.28600000000000003
# [500 450 580   0 670]
# UACH/química farmacia, prob: 0.11
# USACH/química farmacia, prob: 0.22466666666666668
# USACH/química licenciatura química, prob: 0.418
# [400 430   0 450 500]
# UMAYO/psicología, prob: 0.14457142857142857
# UNAP/sociología, prob: 0.45476190476190476
# UNAP/trabajo social, prob: 0.18
# [620 730   0 680 620]
# UCH/lengua literatura hispánicas, prob: 0.1818888888888889
# PUC/college ciencias sociales, prob: 0.233047619047619
# UDEC/derecho, prob: 0.37939682539682534
# 1_data.csv
# accurracy: 0.2564575645756458
# accurracy: 0.23616236162361623
# accurracy: 0.24723247232472326
# accurracy: 0.2693726937269373
# accurracy: 0.23616236162361623
# [830 700 778   0 720]
# UCH/contador auditor  lic  contabilidad auditoría , prob: 0.03
# UCH/ingenieria comercial, prob: 0.2806666666666667
# PUC/ingeniería comercial, prob: 0.6713333333333334
# [830 700 778 680 720]
# UCH/contador auditor  lic  contabilidad auditoría , prob: 0.03
# UCH/ingenieria comercial, prob: 0.28933333333333333
# PUC/ingeniería comercial, prob: 0.6626666666666666
# [500 450 580   0 670]
# USACH/contador público auditor, prob: 0.10400000000000001
# UPA/ingeniería comercial, prob: 0.28749206349206347
# UNAB/contador auditor, prob: 0.3041904761904762
# [400 430   0 450 500]
# UMAYO/ingeniería administración, prob: 0.13390476190476192
# UNAP/ingeniería comercial, prob: 0.15593650793650793
# UNAB/contador auditor, prob: 0.33371428571428574
# [620 730   0 680 620]
# USACH/ingeniería comercial, prob: 0.14400000000000002
# UCH/administración pública, prob: 0.23199999999999998
# USACH/administración pública, prob: 0.44333333333333336
# 4_data.csv
# accurracy: 0.2958199356913183
# accurracy: 0.3054662379421222
# accurracy: 0.2508038585209003
# accurracy: 0.27009646302250806
# accurracy: 0.2990353697749196
# [830 700 778   0 720]
# UCH/programa académico bachillerato, prob: 0.12533333333333335
# PUC/física, prob: 0.228
# UCH/ingeniería biotecnología molecular, prob: 0.14333333333333334
# [830 700 778 680 720]
# UCH/ingeniería biotecnología molecular, prob: 0.11599999999999999
# PUC/química farmacia, prob: 0.16466666666666668
# UCH/pedadogía ed  media matemática física, prob: 0.18638095238095237
# [500 450 580   0 670]
# PUCV/bioquímica, prob: 0.12638095238095237
# ULS/química, prob: 0.21546031746031746
# UFRO/bioquímica, prob: 0.21933333333333338
# [400 430   0 450 500]
# PUCV/geografía, prob: 0.10266666666666666
# UNAB/química farmacia, prob: 0.26095238095238094
# UTA/ingeniería química ambiental, prob: 0.30952380952380953
# [620 730   0 680 620]
# UCH/periodismo, prob: 0.1805714285714286
# UCH/cine televisión, prob: 0.18238095238095242
# UCH/programa académico bachillerato, prob: 0.46838095238095234
# 10_data.csv
# accurracy: 0.16054564533053514
# accurracy: 0.161594963273872
# accurracy: 0.17523609653725078
# accurracy: 0.16054564533053514
# accurracy: 0.1626442812172088
# [830 700 778   0 720]
# PUC/astronomía, prob: 0.2426666666666667
# UCN/geología, prob: 0.2686666666666667
# UDEC/geología, prob: 0.324
# [830 700 778 680 720]
# PUCV/licenciatura ciencias artes musicales, prob: 0.0880952380952381
# PUC/astronomía, prob: 0.30838095238095237
# UDEC/geología, prob: 0.225
# [500 450 580   0 670]
# UDEC/biología, prob: 0.11261904761904763
# UNAB/geología, prob: 0.142
# UACH/bioquímica , prob: 0.14465367965367965
# [400 430   0 450 500]
# UNAB/diseño gráfico, prob: 0.04971428571428572
# UNAB/ecoturismo, prob: 0.07733333333333334
# UNAB/trabajo social, prob: 0.6397142857142857
# [620 730   0 680 620]
# UFT/literatura, prob: 0.09
# UDEC/ciencias políticas administrativas, prob: 0.09799999999999999
# PUC/antropología, prob: 0.251
