# %%
import numpy as np
import pandas as pd
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.preprocessing import scale,LabelEncoder
from sklearn.model_selection import StratifiedShuffleSplit,train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib

# %%
def print_metrics(y_true,y_pred):
    print("accurracy: {}".format(accuracy_score(y_true,y_pred)))
    #print("f1: {}".format(f1_score(y_true,y_pred,average="macro")))

# %%
data_folder = '../../preprocessed_data/area_data'
result_folder = '../../serialized/forest'

# %%
test_scores = np.array(pd.read_csv('test_recomendations.csv'))
for file in os.listdir(data_folder):
    data = pd.read_csv(os.path.join(data_folder, file))
    X = np.array(data[["mat","len","cie","his","nem"]])
    y = np.array(data.apply(lambda x: "{}/{}".format(x['universidad'],x['tuni_carreer_name']),axis=1))
#     lb = LabelEncoder()
#     lb.fit(y)
#     y_encoded = lb.transform(y)
    #X_scaled = scale(X)
    #randomized stratified test/train split
    print(file)
    sss = StratifiedShuffleSplit(n_splits=5, train_size=0.8, random_state=0)
    try:
        for train_index,test_index in sss.split(X, y):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            model = RandomForestClassifier(25,min_samples_split=5,n_jobs=-1)
            model.fit(X_train,y_train)
            result = model.predict(X_test)
            print_metrics(y_test,result)
    except ValueError:
        print("{} failed!".format(file))
    model = RandomForestClassifier(25,min_samples_split=5,n_jobs=-1)
    model.fit(X,y)
    clases = model.classes_
    result = model.predict_proba(test_scores)
    for i in range(test_scores.shape[0]):
        print(test_scores[i])
        best = np.argpartition(result[i],-3)[-3:]
        for index in best:
            print("{}, prob: {}".format(clases[index],result[i][index]))
    joblib.dump(model,os.path.join(result_folder,os.path.splitext(file)[0]))
# Out:
# 9_data.csv
# accurracy: 0.10080490609428899
# accurracy: 0.09505557684936758
# accurracy: 0.10195477194327328
# accurracy: 0.09505557684936758
# accurracy: 0.09620544269835186
# [830 700 778   0 720]
# UACH/medicina , prob: 0.15103174603174602
# UFRO/medicina, prob: 0.2361111111111111
# UCH/medicina , prob: 0.38833333333333336
# [830 700 778 680 720]
# UACH/medicina , prob: 0.14633333333333332
# UFRO/medicina, prob: 0.15388888888888888
# UCH/medicina , prob: 0.3428888888888889
# [500 450 580   0 670]
# UPA/nutrición dietética, prob: 0.08933333333333333
# UNAB/medicina veterinaria, prob: 0.11066666666666666
# UNAB/nutrición dietética, prob: 0.12399999999999999
# [400 430   0 450 500]
# UMAYO/medicina veterinaria, prob: 0.13333333333333333
# UNAB/psicología, prob: 0.15333333333333332
# UTA/psicología, prob: 0.2477777777777778
# [620 730   0 680 620]
# UDEC/psicología, prob: 0.09300000000000001
# USACH/psicología, prob: 0.126
# UDP/psicología, prob: 0.5579523809523809
# 2_data.csv
# accurracy: 0.2978723404255319
# accurracy: 0.3262411347517731
# accurracy: 0.3120567375886525
# accurracy: 0.3262411347517731
# accurracy: 0.2695035460992908
# [830 700 778   0 720]
# UTAL/agronomía, prob: 0.09733333333333333
# UCH/ingeniería agrónoma, prob: 0.3134285714285714
# UCH/ingeniería recursos naturales renovables, prob: 0.5692380952380952
# [830 700 778 680 720]
# UTAL/agronomía, prob: 0.09733333333333333
# UCH/ingeniería agrónoma, prob: 0.30742857142857144
# UCH/ingeniería recursos naturales renovables, prob: 0.5652380952380952
# [500 450 580   0 670]
# UACH/agronomía , prob: 0.14300000000000002
# UCM/agronomía, prob: 0.152
# UDEC/agronomía, prob: 0.28438095238095235
# [400 430   0 450 500]
# UMAYO/agronomía, prob: 0.0737142857142857
# UCT/agronomía, prob: 0.4600952380952381
# UMAYO/ingeniería forestal, prob: 0.23276190476190475
# [620 730   0 680 620]
# UMAYO/agronomía, prob: 0.04833333333333333
# UCH/ingeniería recursos naturales renovables, prob: 0.061
# UCH/ingeniería agrónoma, prob: 0.7523333333333333
# 11_data.csv
# accurracy: 0.09050823857043397
# accurracy: 0.0877233696913437
# accurracy: 0.07936876305407287
# accurracy: 0.07913669064748201
# accurracy: 0.08888373172429798
# [830 700 778   0 720]
# PUCV/ingeniería civil bioquímica, prob: 0.02
# UCH/ingeniería ciencias   plan común, prob: 0.9153333333333333
# UTFSM/ingeniería civil, prob: 0.02333333333333333
# [830 700 778 680 720]
# UTFSM/licenciatura ciencias mención física, prob: 0.044000000000000004
# PUC/ingeniería, prob: 0.10657142857142858
# UCH/ingeniería ciencias   plan común, prob: 0.7756190476190475
# [500 450 580   0 670]
# USACH/ingeniería ejecución mecánica, prob: 0.075
# UFRO/ingeniería civil ambiental, prob: 0.11133333333333333
# UNAB/tecnología médica, prob: 0.10771428571428572
# [400 430   0 450 500]
# UNAB/ingeniería administración hotelera internacional, prob: 0.11
# UNAB/ingeniería industrial, prob: 0.12333333333333332
# UNAB/ingeniería administración empresas, prob: 0.293
# [620 730   0 680 620]
# UDP/ingeniería comercial, prob: 0.08171428571428571
# PUCV/ingeniería civil informática, prob: 0.105
# UAI/ingeniería comercial, prob: 0.30032234432234434
# 7_data.csv
# 7_data.csv failed!
# [830 700 778   0 720]
# USACH/pedagogía física matemática   licenciatura educación física matemática , prob: 0.18066666666666667
# PUC/pedagogía educación media matemática, prob: 0.2516666666666667
# USACH/bachillerato ciencias humanidades , prob: 0.2051111111111111
# [830 700 778 680 720]
# UMCE/lic  educación pedagogía música, prob: 0.10133333333333333
# PUC/pedagogía educación media matemática, prob: 0.14666666666666667
# UACH/pedagogía historia ciencias sociales, prob: 0.1733333333333333
# [500 450 580   0 670]
# UCM/pedagogía educación física, prob: 0.07857142857142857
# UBB/pedagogía ciencias naturales, prob: 0.09333333333333334
# UNAB/educación física, prob: 0.11466666666666667
# [400 430   0 450 500]
# UNAB/psicopedagogía, prob: 0.11647619047619047
# UNAB/educación física, prob: 0.4605714285714286
# UNAB/educación general básica, prob: 0.1686190476190476
# [620 730   0 680 620]
# UDD/pedagogía educación básica, prob: 0.098
# UMAYO/pedagogía educación diferencial mención discapacidades intelectual múltiples, prob: 0.10133333333333333
# PUCV/psicología, prob: 0.11266666666666668
# 6_data.csv
# accurracy: 0.33059548254620125
# accurracy: 0.2751540041067762
# accurracy: 0.3264887063655031
# accurracy: 0.33059548254620125
# accurracy: 0.3162217659137577
# [830 700 778   0 720]
# UCN/derecho   sede coquimbo, prob: 0.18095238095238095
# UCH/derecho  lic  ciencias jurídicas sociales, prob: 0.19200000000000003
# UDD/derecho   santiago, prob: 0.2323809523809524
# [830 700 778 680 720]
# UDD/derecho   santiago, prob: 0.048
# PUC/derecho, prob: 0.3871111111111111
# UCH/derecho  lic  ciencias jurídicas sociales, prob: 0.42088888888888887
# [500 450 580   0 670]
# UCSC/derecho, prob: 0.16133333333333333
# UNAB/derecho, prob: 0.2053333333333333
# UDD/derecho   santiago, prob: 0.18200000000000002
# [400 430   0 450 500]
# UCN/derecho   sede coquimbo, prob: 0.0
# UV/derecho, prob: 0.0
# UNAB/derecho, prob: 1.0
# [620 730   0 680 620]
# PUCV/derecho, prob: 0.10466666666666669
# UAI/derecho, prob: 0.32
# UDP/derecho, prob: 0.25133333333333335
# 3_data.csv
# accurracy: 0.1080669710806697
# accurracy: 0.1156773211567732
# accurracy: 0.1293759512937595
# accurracy: 0.1050228310502283
# accurracy: 0.1248097412480974
# [830 700 778   0 720]
# UAI/diseño, prob: 0.03333333333333333
# UTFSM/arquitectura, prob: 0.272
# PUC/arquitectura, prob: 0.628
# [830 700 778 680 720]
# PUC/diseño, prob: 0.06133333333333333
# UCH/artes plásticas, prob: 0.1103809523809524
# PUC/arquitectura, prob: 0.5403333333333332
# [500 450 580   0 670]
# UMAYO/arquitectura, prob: 0.11200000000000002
# UTA/diseño multimedia, prob: 0.15047619047619049
# UNAB/arquitectura, prob: 0.1643174603174603
# [400 430   0 450 500]
# UFT/diseño, prob: 0.08800000000000001
# UNAB/artes visuales, prob: 0.09633333333333333
# UNAB/arquitectura, prob: 0.4153333333333334
# [620 730   0 680 620]
# UCH/teoría música, prob: 0.096
# PUC/arte, prob: 0.09966666666666665
# UCH/diseño, prob: 0.10155555555555555
# 8_data.csv
# accurracy: 0.5833333333333334
# accurracy: 0.6111111111111112
# accurracy: 0.6944444444444444
# accurracy: 0.6111111111111112
# accurracy: 0.5555555555555556
# [830 700 778   0 720]
# UTA/licenciatura lenguaje comunicación, prob: 0.12666666666666665
# UANDE/bachillerato humanidades, prob: 0.3257142857142857
# PUC/filosofía, prob: 0.2759523809523809
# [830 700 778 680 720]
# USACH/licenciatura historia , prob: 0.07566666666666666
# PUC/historia, prob: 0.39799999999999996
# PUC/filosofía, prob: 0.4579523809523809
# [500 450 580   0 670]
# UTA/licenciatura inglés, prob: 0.12666666666666668
# UNAP/traducción inglés   español, prob: 0.13666666666666666
# UTA/licenciatura lenguaje comunicación, prob: 0.5466666666666666
# [400 430   0 450 500]
# UDEC/licenciatura historia, prob: 0.044000000000000004
# UNAP/traducción inglés   español, prob: 0.6927619047619048
# UTA/licenciatura lenguaje comunicación, prob: 0.24323809523809525
# [620 730   0 680 620]
# USACH/licenciatura historia , prob: 0.12
# PUC/historia, prob: 0.3606190476190476
# PUC/filosofía, prob: 0.496047619047619
# 5_data.csv
# accurracy: 0.23201856148491878
# accurracy: 0.25754060324825984
# accurracy: 0.23433874709976799
# accurracy: 0.2505800464037123
# accurracy: 0.2088167053364269
# [830 700 778   0 720]
# PUC/biología, prob: 0.10300000000000001
# PUC/bioquímica, prob: 0.4663809523809524
# UACH/geología , prob: 0.2889523809523809
# [830 700 778 680 720]
# PUC/college ciencias sociales, prob: 0.14733333333333334
# UCH/psicología  lic  psicología , prob: 0.14733333333333337
# UCH/antropología    arquelogía  lic  antropología mención antropología, prob: 0.2717142857142857
# [500 450 580   0 670]
# UDEC/antropología, prob: 0.10476190476190475
# UACH/química farmacia, prob: 0.11838095238095239
# USACH/química licenciatura química, prob: 0.39533333333333337
# [400 430   0 450 500]
# UMAYO/psicología, prob: 0.11599999999999999
# UNAP/trabajo social, prob: 0.27276190476190476
# UNAP/sociología, prob: 0.2981904761904762
# [620 730   0 680 620]
# PUC/college ciencias sociales, prob: 0.1503809523809524
# UCH/lengua literatura hispánicas, prob: 0.26266666666666666
# UDEC/derecho, prob: 0.27476190476190476
# 1_data.csv
# accurracy: 0.25092250922509224
# accurracy: 0.24538745387453875
# accurracy: 0.2564575645756458
# accurracy: 0.2822878228782288
# accurracy: 0.24354243542435425
# [830 700 778   0 720]
# UCH/administración pública, prob: 0.02
# UCH/ingenieria comercial, prob: 0.2884444444444444
# PUC/ingeniería comercial, prob: 0.6915555555555555
# [830 700 778 680 720]
# UCH/administración pública, prob: 0.02
# UCH/ingenieria comercial, prob: 0.28476190476190477
# PUC/ingeniería comercial, prob: 0.6952380952380952
# [500 450 580   0 670]
# UACH/auditoría, prob: 0.11933333333333333
# UPA/ingeniería comercial, prob: 0.28
# UMAYO/ingeniería administración, prob: 0.198
# [400 430   0 450 500]
# UTA/contador auditor   contador público, prob: 0.214
# UNAB/contador auditor, prob: 0.258
# UMAYO/ingeniería administración, prob: 0.27
# [620 730   0 680 620]
# UCH/administración pública, prob: 0.18600000000000003
# USACH/administración pública, prob: 0.3300952380952381
# USACH/ingeniería comercial, prob: 0.24333333333333332
# 4_data.csv
# accurracy: 0.2861736334405145
# accurracy: 0.2765273311897106
# accurracy: 0.2765273311897106
# accurracy: 0.22186495176848875
# accurracy: 0.31511254019292606
# [830 700 778   0 720]
# UCH/quimica  lic química, prob: 0.15514285714285714
# UCH/ingeniería biotecnología molecular, prob: 0.20609523809523808
# PUC/física, prob: 0.311047619047619
# [830 700 778 680 720]
# PUC/física, prob: 0.15361904761904763
# UCH/ingeniería biotecnología molecular, prob: 0.15876190476190474
# UCH/pedadogía ed  media matemática física, prob: 0.28514285714285714
# [500 450 580   0 670]
# PUCV/bioquímica, prob: 0.12804761904761905
# UTA/ingeniería química ambiental, prob: 0.27385714285714285
# UNAB/química farmacia, prob: 0.15238095238095237
# [400 430   0 450 500]
# UDEC/bachillerato humanidades, prob: 0.15742857142857145
# UNAB/química farmacia, prob: 0.23866666666666667
# UTA/ingeniería química ambiental, prob: 0.37266666666666665
# [620 730   0 680 620]
# UCH/cine televisión, prob: 0.1791111111111111
# UCH/periodismo, prob: 0.2603636363636364
# UCH/programa académico bachillerato, prob: 0.43243001443001433
# 10_data.csv
# accurracy: 0.15110178384050368
# accurracy: 0.1584470094438615
# accurracy: 0.15110178384050368
# accurracy: 0.1458551941238195
# accurracy: 0.1521511017838405
# [830 700 778   0 720]
# PUC/college ciencias naturales matemáticas, prob: 0.21866666666666668
# UCN/geología, prob: 0.22780952380952382
# UDEC/geología, prob: 0.25066666666666665
# [830 700 778 680 720]
# PUCV/licenciatura ciencias artes musicales, prob: 0.11304761904761904
# UDEC/geología, prob: 0.2177777777777778
# PUC/astronomía, prob: 0.1496825396825397
# [500 450 580   0 670]
# UNAB/licenciatura biología, prob: 0.07
# UDEC/biología, prob: 0.07666666666666666
# UCN/biología marina, prob: 0.07733333333333334
# [400 430   0 450 500]
# UNAB/publicidad, prob: 0.06
# UNAB/diseño gráfico, prob: 0.08533333333333333
# UNAB/trabajo social, prob: 0.595
# [620 730   0 680 620]
# PUC/letras hispánicas, prob: 0.09685714285714285
# PUCV/ingeniería civil industrial, prob: 0.11314285714285716
# PUC/antropología, prob: 0.3008095238095238
