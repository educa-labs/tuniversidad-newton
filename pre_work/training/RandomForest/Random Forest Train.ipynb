# %%
import numpy as np
import pandas as pd
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.preprocessing import scale,LabelEncoder
from sklearn.model_selection import StratifiedShuffleSplit,train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib

# %%
def print_metrics(y_true,y_pred):
    print("accurracy: {}".format(accuracy_score(y_true,y_pred)))
    #print("f1: {}".format(f1_score(y_true,y_pred,average="macro")))

# %%
data_folder = '../../preprocessed_data/area_data'
result_folder = '../../serialized/forest'

# %%
test_scores = np.array(pd.read_csv('test_recomendations.csv'))
for file in os.listdir(data_folder):
    data = pd.read_csv(os.path.join(data_folder, file))
    X = np.array(data[["mat","len","cie","his","nem"]])
    #y = np.array(data.apply(lambda x: "{}/{}".format(x['universidad'],x['tuni_carreer_name']),axis=1))
    y = np.array(data['tuni_carreer_id'])
#     lb = LabelEncoder()
#     lb.fit(y)
#     y_encoded = lb.transform(y)
    #X_scaled = scale(X)
    #randomized stratified test/train split
    print(file)
    sss = StratifiedShuffleSplit(n_splits=5, train_size=0.8, random_state=0)
    try:
        for train_index,test_index in sss.split(X, y):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            model = RandomForestClassifier(25,min_samples_split=5,n_jobs=-1)
            model.fit(X_train,y_train)
            result = model.predict(X_test)
            print_metrics(y_test,result)
    except ValueError:
        print("{} failed!".format(file))
    model = RandomForestClassifier(25,min_samples_split=5,n_jobs=-1)
    model.fit(X,y)
    clases = model.classes_
    result = model.predict_proba(test_scores)
    for i in range(test_scores.shape[0]):
        print(test_scores[i])
        best = np.argpartition(result[i],-3)[-3:]
        for index in best:
            print("{}, prob: {}".format(clases[index],result[i][index]))
    joblib.dump(model,os.path.join(result_folder,os.path.splitext(file)[0]))
# Out:
# 9_data.csv
# accurracy: 0.1000383288616328
# accurracy: 0.09773859716366425
# accurracy: 0.09965504024530472
# accurracy: 0.1004216174779609
# accurracy: 0.10195477194327328
# [830 700 778   0 720]
# 402, prob: 0.1562857142857143
# 538, prob: 0.22590476190476189
# 58, prob: 0.4091428571428572
# [830 700 778 680 720]
# 402, prob: 0.10695238095238095
# 538, prob: 0.26590476190476187
# 58, prob: 0.4024761904761905
# [500 450 580   0 670]
# 1308, prob: 0.08085714285714285
# 1144, prob: 0.1
# 728, prob: 0.10400000000000001
# [400 430   0 450 500]
# 672, prob: 0.098
# 1308, prob: 0.13606349206349205
# 846, prob: 0.30433333333333334
# [620 730   0 680 620]
# 965, prob: 0.08444444444444445
# 262, prob: 0.11266666666666665
# 452, prob: 0.6015555555555556
# 2_data.csv
# accurracy: 0.3475177304964539
# accurracy: 0.28368794326241137
# accurracy: 0.3262411347517731
# accurracy: 0.2907801418439716
# accurracy: 0.3262411347517731
# [830 700 778   0 720]
# 370, prob: 0.14133333333333334
# 20, prob: 0.29355555555555557
# 21, prob: 0.4566666666666667
# [830 700 778 680 720]
# 370, prob: 0.07333333333333333
# 20, prob: 0.3855555555555556
# 21, prob: 0.4633333333333334
# [500 450 580   0 670]
# 1099, prob: 0.13866666666666666
# 370, prob: 0.17966666666666664
# 119, prob: 0.2786666666666667
# [400 430   0 450 500]
# 1280, prob: 0.19444444444444442
# 1303, prob: 0.22253968253968254
# 1045, prob: 0.27844444444444444
# [620 730   0 680 620]
# 21, prob: 0.04666666666666666
# 973, prob: 0.04857142857142858
# 20, prob: 0.8170476190476191
# 11_data.csv
# accurracy: 0.08934787653747969
# accurracy: 0.09074031097702483
# accurracy: 0.08331399396611743
# accurracy: 0.09120445579020654
# accurracy: 0.08865165931770712
# [830 700 778   0 720]
# 284, prob: 0.01
# 91, prob: 0.12
# 22, prob: 0.8531111111111112
# [830 700 778 680 720]
# 309, prob: 0.05
# 91, prob: 0.17833333333333332
# 22, prob: 0.6217777777777778
# [500 450 580   0 670]
# 228, prob: 0.08514285714285715
# 753, prob: 0.09723809523809525
# 310, prob: 0.096
# [400 430   0 450 500]
# 706, prob: 0.08266666666666665
# 702, prob: 0.08895238095238095
# 694, prob: 0.4606666666666666
# [620 730   0 680 620]
# 919, prob: 0.11333333333333333
# 503, prob: 0.26666666666666666
# 434, prob: 0.13047619047619047
# 7_data.csv
# 7_data.csv failed!
# [830 700 778   0 720]
# 211, prob: 0.15161904761904763
# 256, prob: 0.21823809523809523
# 105, prob: 0.2883809523809524
# [830 700 778 680 720]
# 999, prob: 0.09533333333333333
# 1338, prob: 0.10476190476190475
# 105, prob: 0.25933333333333336
# [500 450 580   0 670]
# 668, prob: 0.06920634920634922
# 644, prob: 0.20230158730158732
# 374, prob: 0.1057142857142857
# [400 430   0 450 500]
# 745, prob: 0.1420952380952381
# 667, prob: 0.19165079365079368
# 663, prob: 0.2666825396825397
# [620 730   0 680 620]
# 1336, prob: 0.10585714285714286
# 364, prob: 0.14333333333333334
# 208, prob: 0.2163809523809524
# 6_data.csv
# accurracy: 0.3141683778234086
# accurracy: 0.32238193018480493
# accurracy: 0.33675564681724846
# accurracy: 0.33675564681724846
# accurracy: 0.3347022587268994
# [830 700 778   0 720]
# 944, prob: 0.14666666666666667
# 903, prob: 0.1726190476190476
# 768, prob: 0.24671428571428572
# [830 700 778 680 720]
# 610, prob: 0.055999999999999994
# 81, prob: 0.2713333333333333
# 46, prob: 0.5586666666666666
# [500 450 580   0 670]
# 1357, prob: 0.1
# 809, prob: 0.12
# 654, prob: 0.5136666666666667
# [400 430   0 450 500]
# 1653, prob: 0.021333333333333333
# 809, prob: 0.11333333333333333
# 654, prob: 0.8453333333333332
# [620 730   0 680 620]
# 463, prob: 0.12276190476190475
# 427, prob: 0.19885714285714287
# 492, prob: 0.27076190476190476
# 3_data.csv
# accurracy: 0.1019786910197869
# accurracy: 0.1095890410958904
# accurracy: 0.1156773211567732
# accurracy: 0.1035007610350076
# accurracy: 0.1095890410958904
# [830 700 778   0 720]
# 494, prob: 0.07333333333333332
# 70, prob: 0.5703809523809524
# 305, prob: 0.21542857142857144
# [830 700 778 680 720]
# 305, prob: 0.06
# 83, prob: 0.07333333333333333
# 70, prob: 0.5603333333333333
# [500 450 580   0 670]
# 1487, prob: 0.11
# 763, prob: 0.11390476190476191
# 1282, prob: 0.13333333333333333
# [400 430   0 450 500]
# 1282, prob: 0.12
# 811, prob: 0.136
# 642, prob: 0.25999999999999995
# [620 730   0 680 620]
# 10, prob: 0.09466666666666666
# 99, prob: 0.10666666666666667
# 2, prob: 0.10133333333333333
# 8_data.csv
# accurracy: 0.4722222222222222
# accurracy: 0.8055555555555556
# accurracy: 0.5833333333333334
# accurracy: 0.6111111111111112
# accurracy: 0.6111111111111112
# [830 700 778   0 720]
# 86, prob: 0.1520952380952381
# 831, prob: 0.25533333333333336
# 612, prob: 0.3534285714285714
# [830 700 778 680 720]
# 248, prob: 0.10400000000000001
# 90, prob: 0.3841904761904762
# 86, prob: 0.3918095238095238
# [500 450 580   0 670]
# 1478, prob: 0.11533333333333332
# 831, prob: 0.3459999999999999
# 612, prob: 0.35200000000000004
# [400 430   0 450 500]
# 90, prob: 0.0
# 831, prob: 0.44699999999999995
# 1478, prob: 0.5529999999999999
# [620 730   0 680 620]
# 612, prob: 0.08
# 90, prob: 0.27799999999999997
# 86, prob: 0.522
# 5_data.csv
# accurracy: 0.21809744779582366
# accurracy: 0.23897911832946636
# accurracy: 0.22041763341067286
# accurracy: 0.25754060324825984
# accurracy: 0.19721577726218098
# [830 700 778   0 720]
# 73, prob: 0.13166666666666665
# 384, prob: 0.21533333333333332
# 75, prob: 0.39299999999999996
# [830 700 778 680 720]
# 43, prob: 0.145
# 40, prob: 0.19066666666666665
# 42, prob: 0.2816666666666667
# [500 450 580   0 670]
# 1289, prob: 0.10133333333333333
# 265, prob: 0.3826666666666667
# 79, prob: 0.10933333333333332
# [400 430   0 450 500]
# 1289, prob: 0.12
# 1477, prob: 0.27166666666666667
# 1476, prob: 0.3565714285714286
# [620 730   0 680 620]
# 53, prob: 0.21203174603174602
# 79, prob: 0.2363174603174603
# 134, prob: 0.2642539682539683
# 1_data.csv
# accurracy: 0.25092250922509224
# accurracy: 0.25092250922509224
# accurracy: 0.25461254612546125
# accurracy: 0.25276752767527677
# accurracy: 0.24907749077490776
# [830 700 778   0 720]
# 49, prob: 0.008
# 48, prob: 0.126
# 92, prob: 0.866
# [830 700 778 680 720]
# 49, prob: 0.008
# 48, prob: 0.225
# 92, prob: 0.767
# [500 450 580   0 670]
# 213, prob: 0.10466666666666667
# 651, prob: 0.1346031746031746
# 1980, prob: 0.3475555555555555
# [400 430   0 450 500]
# 808, prob: 0.14600000000000002
# 1301, prob: 0.20533333333333334
# 651, prob: 0.38800000000000007
# [620 730   0 680 620]
# 213, prob: 0.19495238095238096
# 209, prob: 0.29285714285714287
# 64, prob: 0.3906666666666667
# 4_data.csv
# accurracy: 0.2829581993569132
# accurracy: 0.27009646302250806
# accurracy: 0.2733118971061093
# accurracy: 0.2733118971061093
# accurracy: 0.2861736334405145
# [830 700 778   0 720]
# 38, prob: 0.14447619047619045
# 16, prob: 0.22333333333333333
# 87, prob: 0.264
# [830 700 778 680 720]
# 13, prob: 0.10766666666666666
# 16, prob: 0.185
# 18, prob: 0.20600000000000002
# [500 450 580   0 670]
# 827, prob: 0.1217142857142857
# 513, prob: 0.1652380952380952
# 315, prob: 0.19547619047619047
# [400 430   0 450 500]
# 127, prob: 0.07466666666666667
# 749, prob: 0.3143809523809524
# 827, prob: 0.32736507936507936
# [620 730   0 680 620]
# 109, prob: 0.18704761904761905
# 66, prob: 0.19866666666666666
# 7, prob: 0.5416190476190477
# 10_data.csv
# accurracy: 0.14900314795383002
# accurracy: 0.15634837355718784
# accurracy: 0.15739769150052466
# accurracy: 0.1521511017838405
# accurracy: 0.15634837355718784
# [830 700 778   0 720]
# 147, prob: 0.18333333333333335
# 770, prob: 0.22352380952380954
# 78, prob: 0.2614285714285714
# [830 700 778 680 720]
# 145, prob: 0.12266666666666666
# 770, prob: 0.16314285714285715
# 78, prob: 0.184
# [500 450 580   0 670]
# 805, prob: 0.09266666666666666
# 848, prob: 0.10866666666666668
# 129, prob: 0.09857142857142857
# [400 430   0 450 500]
# 660, prob: 0.08266666666666665
# 659, prob: 0.14844444444444443
# 759, prob: 0.4704444444444445
# [620 730   0 680 620]
# 331, prob: 0.07633333333333332
# 1370, prob: 0.09944444444444443
# 69, prob: 0.41022222222222227
