# %%
import pandas as pd

# %%
carreer_data = pd.read_csv('../preprocessed_data/carreras2.csv',index_col=0)
areas = pd.read_csv('../data/tuni/carreer_areas.csv',index_col=0)
carreer_data
# Out:
#                                              Nombre  \
# ID
# 1                                 Actuación Teatral
# 2                                   Artes Plásticas
# 3                                    Diseño Teatral
# 4                              Ingeniería en Sonido
# 5                               Teoría de la Música
# 6                        Teoría e Historia del Arte
# 7                   Programa Académico Bachillerato
# 8                                      Arquitectura
# 9                                            Diseño
# 10                                        Geografía
# 11                                         Biología
# 12                                           Física
# 13                                      Matemáticas
# 14                                          Química
# 15               Biología mención en Medio Ambiente
# 16            Ingeniería en Biotecnología Molecular
# 17     Pedadogía en Ed. Media en Biología y Química
# ...

# %%
for i in carreer_data.index:
    try:
        print(int(carreer_data.loc[i]['area_id']) == int(areas.loc[i]['area_id']))
    except TypeError:
        print(i)
        print(carreer_data.loc[i]['area_id'])
        print(areas.loc[i]['area_id'])
        raise IndexError
    print(carreer_data.loc[i]['area_id'])
    carreer_data.at[i,'area_id'] = areas.loc[i]['area_id']
    carreer_data.at[i,'Área'] = areas.loc[i]['area']
    print(carreer_data.loc[i]['area_id'])
# Out:
# True
# 3
# 3
# True
# 3
# 3
# True
# 3
# 3
# True
# 3
# 3
# True
# 3
# 3
# True
# 3
# 3
# True
# 4
# 4
# True
# 3
# 3
# True
# 3
# 3
# False
# 3
# 8
# True
# 4
# 4
# True
# 4
# 4
# True
# 4
# 4
# True
# 4
# 4
# True
# 4
# 4
# True
# 4
# 4
# True
# 4
# 4
# True
# 4
# 4
# True
# 4
# 4
# True
# 2
# 2
# True
# 2
# 2
# True
# 11
# 11
# True
# 11
# 11
# True
# 11
# 11
# True
# 11
# 11
# True
# 11
# 11
# True
# 11
# 11
# True
# 11
# 11
# True
# 11
# 11
# True
# 11
# 11
# False
# 10
# 4
# True
# 11
# 11
# True
# 11
# 11
# True
# 11
# 11
# True
# 11
# 11
# True
# 4
# 4
# True
# 4
# 4
# True
# 4
# 4
# True
# 4
# 4
# True
# 5
# 5
# True
# 5
# 5
# True
# 5
# 5
# True
# 5
# 5
# True
# 5
# 5
# True
# 9
# 9
# True
# 6
# 6
# True
# 1
# 1
# True
# 1
# 1
# True
# 1
# 1
# True
# 5
# 5
# True
# 5
# 5
# True
# 5
# 5
# True
# 5
# 5
# True
# 7
# 7
# True
# 9
# 9
# True
# 9
# 9
# True
# 9
# 9
# True
# 9
# 9
# True
# 9
# 9
# True
# 9
# 9
# True
# 9
# 9
# True
# 9
# 9
# True
# 9
# 9
# True
# 1
# 1
# False
# ...

# %%
carreer_data.to_csv('../preprocessed_data/carreras2.csv', index=False, header=peseu_data.columns.values)
