# %%
import numpy as np
from gensim.models import KeyedVectors
from nltk.corpus import stopwords
import pandas as pd
from string import punctuation

# %% [markdown]
# ### String preprocessing functions

# %%
def name_to_list(name):
    try:
        stripped = name.strip()
    except:
        name = str(name)
    word_list = name.split(" ")
    return list(map(lambda x: x.strip().lower(), word_list))

def remove_symbols(word_list):
    for w in range(len(word_list)):
        for char in punctuation:
            if char in word_list[w]:
                word_list[w] = word_list[w].replace(char," ")
    return word_list

def remove_stop_words(word_list):
    words = stopwords.words('spanish')
    return list(filter(lambda x: x not in words, word_list))
    
def preprocess_name(name):
    return remove_stop_words(remove_symbols(name_to_list(name)))
    
def perfect_split(name):
    words = name.split(" ")
    return list(filter(lambda x: x != "",map(lambda y: y.strip(),words)))

# %% [markdown]
# ### Word2Vec functions

# %%
def get_average_vec(words, model):
    vectors = []
    errors = 0
    for word in words:
        if word != " ":
            try:
                vectors.append(model[word])
            except KeyError:
                errors += 1
                print("Error: {}".format(word))
                if errors == len(words):
                    return None
                continue
    #print(errors / len(words))
    return np.mean(np.array(vectors), axis=0)

def create_vector_data(df,model,column,output):
    result = np.zeros((df.shape[0],model.vector_size + 1))
    result[:,0] = df['ID']
    errors = []
    for i in range(df.shape[0]):
        vector = get_average_vec(df[column][i],model)
        if vector is not None:
            result[i,1:] = vector
        else:
            errors.append(i)
    #print(len(errors)) #0
    print(result)
    data = pd.DataFrame(result).to_csv(output, index=False, header=(['id'] + [str(i) for i in range((model.vector_size))]), float_format="%11.17f")
    
def name_similarity(model, n_first, n_second):
    copy_first = list(n_first)
    copy_second = list(n_second)
    while True:
        try:
            return model.n_similarity(copy_first,copy_second)
        except KeyError as err:
            error = str(err).split(" ")[1].strip("'")
            try:
                copy_first.remove(error)
            except:
                copy_second.remove(error)
        except ZeroDivisionError:            
            print(n_first,n_second)
            return 0

# %% [markdown]
# ###  Loading Word2Vec

# %%
model = KeyedVectors.load('trained_vectors')

# %% [markdown]
# ### Load data

# %%
degrees = pd.read_csv('../../preprocessed_data/carreras2.csv')
degrees = degrees[['ID','Nombre','ID Universidad','Área','area_id']]
degrees['Nombre'] = degrees.apply(lambda x : " ".join(preprocess_name(x['Nombre'])),axis=1)
degrees
# Out:
#         ID                                        Nombre  ID Universidad  \
# 0        1                             actuación teatral               1
# 1        2                               artes plásticas               1
# 2        3                                diseño teatral               1
# 3        4                             ingeniería sonido               1
# 4        5                                 teoría música               1
# 5        6                          teoría historia arte               1
# 6        7               programa académico bachillerato               1
# 7        8                                  arquitectura               1
# 8        9                                        diseño               1
# 9       10                                     geografía               1
# 10      11                                      biología               1
# 11      12                                        física               1
# 12      13                                   matemáticas               1
# 13      14                                       química               1
# 14      15               biología mención medio ambiente               1
# 15      16            ingeniería biotecnología molecular               1
# 16      17          pedadogía ed  media biología química               1
# 17      18         pedadogía ed  media matemática física               1
# 18      19                             química ambiental               1
# 19      20                           ingeniería agrónoma               1
# 20      21      ingeniería recursos naturales renovables               1
# 21      22              ingeniería ciencias   plan común               1
# 22      23                      ingeniería civil mención               1
# 23      24                     ingeniería civil mecánica               1
# 24      25                   ingeniería civil matemática               1
# 25      26                ingeniería civil biotecnología               1
# 26      27                    ingeniería civil eléctrica               1
# 27      28                      ingeniería civil química               1
# 28      29                        ingeniería civil minas               1
# 29      30                  ingeniería civil computación               1
# ...    ...                                           ...             ...
# 2602  2602                           nutrición dietética              48
# 2603  2603                           nutrición dietética              48
# 2604  2604                    pedagogía educación física              48
# 2605  2605                 pedagogía educación religiosa              48
# 2606  2606                pedagogía educación parvularia              48
# 2607  2607                         pedagogía matemáticas              48
# 2608  2608                                    periodismo              48
# 2609  2609                                    psicología              48
# 2610  2610                           terapia ocupacional              48
# 2611  2611                           terapia ocupacional              48
# 2612  2612                                trabajo social              48
# 2613  2613                        administración pública              50
# 2614  2614                                     agronomía              50
# 2615  2615                                 biotecnología              50
# 2616  2616                              contador auditor              50
# 2617  2617                                    enfermería              50
# 2618  2618                                fonoaudiología              50
# 2619  2619                  ingeniería civil electrónica              50
# 2620  2620                          ingeniería comercial              50
# 2621  2621              ingeniería ejecución electrónica              50
# 2622  2622  ingeniería ejecución industrias alimentarias              50
# 2623  2623     ingeniería ejecución viticultura enología              50
# 2624  2624                                  kinesiología              50
# 2625  2625                          medicina veterinaria              50
# 2626  2626                           nutrición dietética              50
# 2627  2627                      obstetricia puericultura              50
# 2628  2628                              pedagogía inglés              50
# 2629  2629                   pedagogía matemática física              50
# 2630  2630                             tecnología médica              50
# 2631  2631                                trabajo social              50
#
#                            Área  area_id
# 0           Arte y Arquitectura      3.0
# 1           Arte y Arquitectura      3.0
# 2           Arte y Arquitectura      3.0
# 3           Arte y Arquitectura      3.0
# 4           Arte y Arquitectura      3.0
# 5           Arte y Arquitectura      3.0
# 6              Ciencias Básicas      4.0
# 7           Arte y Arquitectura      3.0
# 8           Arte y Arquitectura      3.0
# 9           Arte y Arquitectura      3.0
# 10             Ciencias Básicas      4.0
# 11             Ciencias Básicas      4.0
# 12             Ciencias Básicas      4.0
# 13             Ciencias Básicas      4.0
# 14             Ciencias Básicas      4.0
# 15             Ciencias Básicas      4.0
# 16             Ciencias Básicas      4.0
# 17             Ciencias Básicas      4.0
# 18             Ciencias Básicas      4.0
# 19                 Agropecuaria      2.0
# 20                 Agropecuaria      2.0
# 21                   Tecnología     11.0
# 22                   Tecnología     11.0
# 23                   Tecnología     11.0
# 24                   Tecnología     11.0
# 25                   Tecnología     11.0
# 26                   Tecnología     11.0
# 27                   Tecnología     11.0
# 28                   Tecnología     11.0
# 29                   Tecnología     11.0
# ...                         ...      ...
# 2602                      Salud      9.0
# 2603                      Salud      9.0
# 2604                  Educación      7.0
# 2605                  Educación      7.0
# 2606                  Educación      7.0
# 2607                  Educación      7.0
# 2608          Ciencias Sociales      5.0
# 2609          Ciencias Sociales      5.0
# 2610                      Salud      9.0
# 2611                      Salud      9.0
# 2612          Ciencias Sociales      5.0
# 2613  Administración y comercio      1.0
# 2614               Agropecuaria      2.0
# 2615                 Tecnología     11.0
# 2616  Administración y comercio      1.0
# 2617                      Salud      9.0
# 2618                      Salud      9.0
# 2619                 Tecnología     11.0
# 2620                 Tecnología     11.0
# 2621                 Tecnología     11.0
# 2622                 Tecnología     11.0
# 2623                 Tecnología     11.0
# 2624                 Tecnología     11.0
# 2625                      Salud      9.0
# 2626                      Salud      9.0
# 2627                      Salud      9.0
# 2628                  Educación      7.0
# 2629                  Educación      7.0
# 2630                      Salud      9.0
# 2631          Ciencias Sociales      5.0
#
# [2632 rows x 5 columns]

# %%
similarity_matrix = np.zeros((degrees.shape[0],degrees.shape[0]))
for i in range(degrees.shape[0]):
    for j in range(i,degrees.shape[0]):
        similarity_matrix[i,j] = name_similarity(model,perfect_split(degrees['Nombre'][i]),perfect_split(degrees['Nombre'][j]))
        similarity_matrix[j,i] = similarity_matrix[i,j]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-c6e5c2c6ce60> in <module>()
#       5         similarity_matrix[i,j] = name_similarity(model,perfect_split(degrees['Nombre'][i]),perfect_split(degrees['Nombre'][j]))
#       6         similarity_matrix[j,i] = similarity_matrix[i,j]
# ----> 7 pickle.dump(similarity_matrix,'../../preprocessed_data/similarity_matrix')
#
# TypeError: file must have a 'write' attribute

# %%
np.save('../../serialized/balltree/similarity_matrix',similarity_matrix)

# %%
#get_average_vec(degrees['title'][0].split(" "),model)
model.n_similarity(degrees['Nombre'][2617].split(" "),degrees['Nombre'][29].split(" "))
# Out:
# 0.43407777458920094

# %% [markdown]
# ### Join Tablas tuni y peseu

# %%
peseu_data = pd.read_csv("peseu_data2.csv")
peseu_data = peseu_data[['id','mat','len','cie','his','nem','carrera','universidad']]
peseu_data['carrera'] = peseu_data.apply(lambda x : " ".join(preprocess_name(x['carrera'])),axis=1)
university_data = pd.read_csv("universidades.tsv", sep='\t')
peseu_data.loc[:,'university_id'] = pd.Series(np.zeros((peseu_data.shape[0]),dtype='int32'),index=peseu_data.index)
peseu_data.loc[:,'tuni_carreer_id'] = pd.Series(np.zeros((peseu_data.shape[0]),dtype='int32'),index=peseu_data.index)
peseu_data.loc[:,'tuni_carreer_name'] = pd.Series(np.zeros((peseu_data.shape[0])),index=peseu_data.index)
peseu_data.loc[:,'tuni_area'] = pd.Series(np.zeros((peseu_data.shape[0])),index=peseu_data.index)
peseu_data.loc[:,'tuni_area_id'] = pd.Series(np.zeros((peseu_data.shape[0]),dtype='int32'),index=peseu_data.index)

# %%
for i in range(university_data.shape[0]):
    booleans = peseu_data['universidad'] == university_data['Sigla'][i]
    peseu_data.loc[booleans,'university_id'] = pd.Series(np.array([university_data['ID'][i]] * len(booleans)))

# %%
id_table = {}
for i in range(peseu_data.shape[0]):
    if not (peseu_data.loc[i,'carrera'],peseu_data.loc[i,'universidad']) in id_table:
        u_carreers = degrees[degrees['ID Universidad'] == peseu_data.loc[i,"university_id"]]
        try:
            most_similar = u_carreers.loc[u_carreers.index[0],:]
        except IndexError:
            print(peseu_data.loc[i,:])
        split_name = perfect_split(peseu_data.loc[i,'carrera'])
        best_similarity = name_similarity(model,split_name,perfect_split(most_similar['Nombre']))
        for j in u_carreers.index:
            similarity = name_similarity(model,split_name,perfect_split(u_carreers.loc[j,'Nombre']))
            if similarity > best_similarity:
                most_similar = u_carreers.loc[j,:]
                best_similarity = similarity
        peseu_data.loc[i,'tuni_carreer_id'] = most_similar['ID']
        peseu_data.loc[i,'tuni_carreer_name'] = most_similar['Nombre']
        peseu_data.loc[i,'tuni_area'] = most_similar['Área']
        peseu_data.loc[i,'tuni_area_id'] = most_similar['area_id']
        id_table[(peseu_data.loc[i,'carrera'],peseu_data.loc[i,'universidad'])] = (most_similar['ID'],most_similar['Nombre'],most_similar['Área'],most_similar['area_id'])
        
    else:
        peseu_data.loc[i,'tuni_carreer_id'] = id_table[(peseu_data.loc[i,'carrera'],peseu_data.loc[i,'universidad'])][0]
        peseu_data.loc[i,'tuni_carreer_name'] = id_table[(peseu_data.loc[i,'carrera'],peseu_data.loc[i,'universidad'])][1]
        peseu_data.loc[i,'tuni_area'] = id_table[(peseu_data.loc[i,'carrera'],peseu_data.loc[i,'universidad'])][2]
        peseu_data.loc[i,'tuni_area_id'] = id_table[(peseu_data.loc[i,'carrera'],peseu_data.loc[i,'universidad'])][3]
    if i % 100 == 0:
        print("progress: {0:.5f}".format(i/peseu_data.shape[0]))
# Out:
# progress: 0.00000
# progress: 0.00083
# progress: 0.00167
# progress: 0.00250
# progress: 0.00334
# progress: 0.00417
# progress: 0.00500
# progress: 0.00584
# progress: 0.00667
# progress: 0.00751
# progress: 0.00834
# progress: 0.00917
# progress: 0.01001
# progress: 0.01084
# progress: 0.01167
# progress: 0.01251
# progress: 0.01334
# progress: 0.01418
# progress: 0.01501
# progress: 0.01584
# progress: 0.01668
# progress: 0.01751
# progress: 0.01835
# progress: 0.01918
# progress: 0.02001
# progress: 0.02085
# progress: 0.02168
# progress: 0.02252
# progress: 0.02335
# progress: 0.02418
# progress: 0.02502
# progress: 0.02585
# progress: 0.02668
# progress: 0.02752
# progress: 0.02835
# progress: 0.02919
# progress: 0.03002
# progress: 0.03085
# progress: 0.03169
# progress: 0.03252
# progress: 0.03336
# progress: 0.03419
# progress: 0.03502
# progress: 0.03586
# progress: 0.03669
# progress: 0.03753
# progress: 0.03836
# progress: 0.03919
# progress: 0.04003
# progress: 0.04086
# progress: 0.04170
# progress: 0.04253
# progress: 0.04336
# progress: 0.04420
# progress: 0.04503
# progress: 0.04586
# progress: 0.04670
# progress: 0.04753
# progress: 0.04837
# progress: 0.04920
# progress: 0.05003
# progress: 0.05087
# progress: 0.05170
# progress: 0.05254
# progress: 0.05337
# progress: 0.05420
# progress: 0.05504
# progress: 0.05587
# progress: 0.05671
# progress: 0.05754
# progress: 0.05837
# progress: 0.05921
# progress: 0.06004
# progress: 0.06087
# progress: 0.06171
# progress: 0.06254
# progress: 0.06338
# progress: 0.06421
# progress: 0.06504
# progress: 0.06588
# progress: 0.06671
# progress: 0.06755
# progress: 0.06838
# progress: 0.06921
# progress: 0.07005
# progress: 0.07088
# progress: 0.07172
# progress: 0.07255
# progress: 0.07338
# progress: 0.07422
# progress: 0.07505
# progress: 0.07589
# progress: 0.07672
# progress: 0.07755
# progress: 0.07839
# progress: 0.07922
# progress: 0.08005
# progress: 0.08089
# progress: 0.08172
# progress: 0.08256
# progress: 0.08339
# progress: 0.08422
# progress: 0.08506
# progress: 0.08589
# progress: 0.08673
# progress: 0.08756
# progress: 0.08839
# progress: 0.08923
# progress: 0.09006
# progress: 0.09090
# progress: 0.09173
# progress: 0.09256
# progress: 0.09340
