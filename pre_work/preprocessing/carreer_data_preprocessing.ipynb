# %%
#resultado tabla de carreras(id,name_descr(300),id_university,arancel,num_semestres,
                            #area,horario_bin,empleabilidad,ingreso,corte,coordenadas_campus)
#usar gower distance para el arbol.
import numpy as np
import pandas as pd
import os

# %%
carreer_vectors = pd.read_csv('../preprocessed_data/vector_carreers.csv')
carreers = pd.read_csv('../preprocessed_data/carreras2.csv')
campus = pd.read_csv('../data/tuni/campuses.tsv', sep='\t')

# %%
carreer_data = carreers[['ID','ID Universidad','ID Campus','Cant. Semestres','Arancel','Empleabilidad','Ingreso','Corte 2017','area_id']]
campus = campus[['ID','Latitud','Longitud']]

# %%
#carreer_data = carreer_data.join(carreer_vectors.set_index('id'),on='ID')
carreer_data = carreer_data.join(campus.set_index('ID'),on='ID', rsuffix='_campus',lsuffix='_carreer')
carreer_data['Empleabilidad'] = carreer_data.apply(lambda x: float(x['Empleabilidad'].replace(',','.')) if type(x['Empleabilidad']) == str else x['Empleabilidad'],axis=1)
carreer_data['Corte 2017'] = carreer_data.apply(lambda x: float(x['Corte 2017'].replace(',','.')) if type(x['Corte 2017']) == str else x['Corte 2017'],axis=1)
carreer_data['Latitud'] = carreer_data.apply(lambda x: float(x['Latitud']) if type(x['Latitud']) == str else x['Latitud'],axis=1)
carreer_data['Longitud'] = carreer_data.apply(lambda x: float(x['Longitud']) if type(x['Longitud']) == str else x['Longitud'],axis=1)
carreer_data['Arancel'] = carreer_data.apply(lambda x: float(x['Arancel'].replace('.','')) if type(x['Arancel']) == str else (x['Arancel']),axis=1)

# %%
carreer_data = carreer_data.fillna(carreer_data.mean())

# %%
carreer_data
# Out:
#         ID  ID Universidad  ID Campus  Cant. Semestres       Arancel  \
# 0        1               1          2             10.0  3.540700e+06
# 1        2               1          2             10.0  2.547000e+06
# 2        3               1          2             10.0  2.547000e+06
# 3        4               1          2             10.0  3.183700e+06
# 4        5               1          7             12.0  2.547000e+06
# 5        6               1          1              8.0  2.794000e+06
# 6        7               1          2              4.0  3.654000e+06
# 7        8               1          3             12.0  3.584100e+06
# 8        9               1          3             10.0  3.584100e+06
# 9       10               1          3             10.0  2.985000e+06
# 10      11               1          1              8.0  3.093600e+06
# 11      12               1          1              8.0  3.093600e+06
# 12      13               1          1              8.0  3.093600e+06
# 13      14               1          1              8.0  3.093600e+06
# 14      15               1          1             10.0  3.351800e+06
# 15      16               1          1             10.0  3.351800e+06
# 16      17               1          1             10.0  3.474300e+06
# 17      18               1          1             10.0  3.474300e+06
# 18      19               1          1             10.0  3.351800e+06
# 19      20               1          6             10.0  3.936700e+06
# 20      21               1          6             10.0  3.936700e+06
# 21      22               1          4             12.0  5.014900e+06
# 22      23               1          4             12.0  5.014900e+06
# 23      24               1          4             12.0  5.014900e+06
# 24      25               1          4             12.0  5.014900e+06
# 25      26               1          4             12.0  5.014900e+06
# 26      27               1          4             12.0  5.014900e+06
# 27      28               1          4             12.0  5.014900e+06
# 28      29               1          4             12.0  5.014900e+06
# 29      30               1          4             12.0  5.014900e+06
# ...    ...             ...        ...              ...           ...
# 2602  2602              48        214             10.0  2.160000e+06
# 2603  2603              48        215             10.0  2.160000e+06
# 2604  2604              48        217             10.0  1.791000e+06
# 2605  2605              48        214              8.0  1.791000e+06
# 2606  2606              48        214              8.0  1.611000e+06
# 2607  2607              48        214             10.0  1.791000e+06
# 2608  2608              48        214              8.0  1.791000e+06
# 2609  2609              48        214             10.0  2.025000e+06
# 2610  2610              48        214             10.0  2.160000e+06
# 2611  2611              48        215             10.0  2.160000e+06
# 2612  2612              48        214             10.0  1.305000e+06
# 2613  2613              50        226             10.0  1.690000e+06
# 2614  2614              50        226             10.0  2.650697e+06
# 2615  2615              50        226             10.0  2.600000e+06
# 2616  2616              50        226              8.0  1.490000e+06
# 2617  2617              50        226             10.0  2.640000e+06
# 2618  2618              50        226             10.0  2.585000e+06
# 2619  2619              50        226             10.0  2.000000e+06
# 2620  2620              50        226             10.0  1.980000e+06
# 2621  2621              50        226              8.0  1.787000e+06
# 2622  2622              50        226              8.0  1.674000e+06
# 2623  2623              50        226              8.0  1.674000e+06
# 2624  2624              50        226             10.0  2.500000e+06
# 2625  2625              50        226             10.0  3.100000e+06
# 2626  2626              50        226             10.0  2.450000e+06
# 2627  2627              50        226             10.0  2.640000e+06
# 2628  2628              50        226             10.0  1.664000e+06
# 2629  2629              50        226             10.0  1.560000e+06
# 2630  2630              50        226             10.0  2.350000e+06
# 2631  2631              50        226              8.0  1.528000e+06
#
#       Empleabilidad       Ingreso  Corte 2017  area_id    Latitud   Longitud
# 0          48.00000  7.000000e+05  601.160000      3.0 -33.465989 -70.597051
# 1          48.00000  7.000000e+05  616.150000      3.0 -33.444501 -70.653068
# 2          77.60000  9.000000e+05  601.150000      3.0 -33.442087 -70.638907
# 3          81.72695  1.136485e+06  638.600000      3.0 -33.457720 -70.665639
# 4          81.72695  1.136485e+06  663.950000      3.0 -33.418291 -70.657432
# 5          81.72695  1.136485e+06  601.100000      3.0 -33.572024 -70.633736
# 6          81.72695  1.136485e+06  669.000000      4.0 -33.442325 -70.664382
# 7          91.50000  1.300000e+06  655.200000      3.0 -33.441128 -70.642982
# 8          77.60000  9.000000e+05  609.700000      3.0 -33.497580 -70.614437
# 9          87.00000  1.200000e+06  620.400000      3.0 -33.419881 -70.619733
# 10         81.72695  1.136485e+06  642.600000      4.0 -33.446918 -70.596605
# 11         81.72695  1.136485e+06  676.500000      4.0 -39.277507 -72.227645
# 12         94.50000  1.136485e+06  642.300000      4.0 -36.829476 -73.036371
# 13         58.80000  1.000000e+06  600.300000      4.0 -36.596754 -72.087006
# 14         81.72695  1.136485e+06  622.500000      4.0 -37.471955 -72.346342
# 15         65.70000  1.300000e+06  705.450000      4.0 -33.451760 -70.688320
# 16         84.10000  9.000000e+05  609.350000      4.0 -33.446619 -70.685612
# 17         94.50000  1.136485e+06  644.600000      4.0 -33.449699 -70.690630
# 18         87.80000  1.400000e+06  600.300000      4.0 -33.034730 -71.630632
# 19         83.70000  1.200000e+06  612.650000      2.0 -33.490096 -70.619540
# 20         90.90000  1.300000e+06  663.800000      2.0 -33.377523 -70.578525
# 21         99.00000  2.100000e+06  722.250000     11.0 -33.038494 -71.503404
# 22         99.00000  2.100000e+06  722.250000     11.0 -36.784902 -73.086815
# 23         92.60000  2.200000e+06  722.250000     11.0 -33.044407 -71.606966
# 24         82.20000  1.136485e+06  722.250000     11.0 -32.896116 -71.211528
# 25         81.72695  1.136485e+06  722.250000     11.0 -33.012716 -71.541514
# 26         95.20000  2.400000e+06  722.250000     11.0 -32.970242 -71.477646
# 27         92.30000  1.136485e+06  722.250000     11.0 -33.026976 -71.583358
# 28         99.00000  2.500000e+06  722.250000     11.0 -33.146000 -71.574341
# 29         94.30000  1.900000e+06  722.250000     11.0 -33.044543 -71.608364
# ...             ...           ...         ...      ...        ...        ...
# 2602       81.72695  1.136485e+06  536.087554      9.0 -33.652802 -71.457381
# 2603       81.72695  1.136485e+06  536.087554      9.0 -33.652802 -71.457381
# 2604       64.10000  1.136485e+06  536.087554      7.0 -33.652802 -71.457381
# 2605       81.72695  1.136485e+06  536.087554      7.0 -33.652802 -71.457381
# 2606       81.72695  1.136485e+06  536.087554      7.0 -33.652802 -71.457381
# 2607       81.72695  1.136485e+06  536.087554      7.0 -33.652802 -71.457381
# 2608       87.50000  1.136485e+06  536.087554      5.0 -33.652802 -71.457381
# 2609       70.10000  1.000000e+06  536.087554      5.0 -33.652802 -71.457381
# 2610       81.72695  1.136485e+06  536.087554      9.0 -33.652802 -71.457381
# 2611       81.72695  1.136485e+06  536.087554      9.0 -33.652802 -71.457381
# 2612       76.60000  1.136485e+06  536.087554      5.0 -33.652802 -71.457381
# 2613       81.72695  1.136485e+06  536.087554      1.0 -33.652802 -71.457381
# 2614       75.40000  1.136485e+06  536.087554      2.0 -33.652802 -71.457381
# 2615       81.72695  1.136485e+06  536.087554     11.0 -33.652802 -71.457381
# 2616       93.90000  1.136485e+06  536.087554      1.0 -33.652802 -71.457381
# 2617       97.40000  1.500000e+06  536.087554      9.0 -33.652802 -71.457381
# 2618       81.72695  1.136485e+06  536.087554      9.0 -33.652802 -71.457381
# 2619       81.72695  1.136485e+06  536.087554     11.0 -33.652802 -71.457381
# 2620       82.00000  1.136485e+06  536.087554     11.0 -33.652802 -71.457381
# 2621       81.72695  1.136485e+06  536.087554     11.0 -33.652802 -71.457381
# 2622       81.72695  1.136485e+06  536.087554     11.0 -33.652802 -71.457381
# 2623       81.72695  1.136485e+06  536.087554     11.0 -33.652802 -71.457381
# 2624       72.40000  1.000000e+06  536.087554     11.0 -33.652802 -71.457381
# 2625       67.70000  9.000000e+05  536.087554      9.0 -33.652802 -71.457381
# 2626       81.72695  1.136485e+06  536.087554      9.0 -33.652802 -71.457381
# 2627       81.72695  1.136485e+06  536.087554      9.0 -33.652802 -71.457381
# 2628       81.72695  1.136485e+06  536.087554      7.0 -33.652802 -71.457381
# 2629       81.72695  1.136485e+06  536.087554      7.0 -33.652802 -71.457381
# 2630       81.72695  1.136485e+06  536.087554      9.0 -33.652802 -71.457381
# 2631       79.50000  1.136485e+06  536.087554      5.0 -33.652802 -71.457381
#
# [2632 rows x 11 columns]

# %%
carreer_data.to_csv('../preprocessed_data/carreers_join.csv', index=False, header=carreer_data.columns.values)
